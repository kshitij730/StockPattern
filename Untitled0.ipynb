# %%
# !pip install tensorflow -qqq
# !pip install keras -qqq
# !pip install yfinance -qqq

# %%
import tensorflow as tf
import keras
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Check TensorFlow version
print("TensorFlow Version: ", tf.__version__)
# Out:
# TensorFlow Version:  2.15.0
# TensorFlow Version:  2.15.0

# %%
# Fetch AAPL data
aapl_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')

# Display the first few rows of the dataframe
aapl_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251122  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251122  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Low'].plot(kind='hist', bins=20, title='Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Low', y='Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Close', y='Adj Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['High'].plot(kind='line', figsize=(8, 4), title='High')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Low'].plot(kind='line', figsize=(8, 4), title='Low')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Close'].plot(kind='line', figsize=(8, 4), title='Close')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Low'].plot(kind='hist', bins=20, title='Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='Low', y='Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='Close', y='Adj Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['High'].plot(kind='line', figsize=(8, 4), title='High')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Low'].plot(kind='line', figsize=(8, 4), title='Low')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['Close'].plot(kind='line', figsize=(8, 4), title='Close')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Fetch AAPL data
aapl_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')

# Display the first few rows of the dataframe
aapl_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251122  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251122  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
aapl_data_scaled = scaler.fit_transform(aapl_data['Close'].values.reshape(-1,1))

# %%
X = []
y = []

for i in range(60, len(aapl_data_scaled)):
    X.append(aapl_data_scaled[i-60:i, 0])
    y.append(aapl_data_scaled[i, 0])

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, AdditiveAttention, Permute, Reshape, Multiply

model = Sequential()

# Adding LSTM layers with return_sequences=True
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=True))

# %%
# Adding self-attention mechanism
# The attention mechanism
attention = AdditiveAttention(name='attention_weight')
# Permute and reshape for compatibility
model.add(Permute((2, 1)))
model.add(Reshape((-1, X_train.shape[1])))
attention_result = attention([model.output, model.output])
multiply_layer = Multiply()([model.output, attention_result])
# Return to original shape
model.add(Permute((2, 1)))
model.add(Reshape((-1, 50)))

# Adding a Flatten layer before the final Dense layer
model.add(tf.keras.layers.Flatten())

# Final Dense layer
model.add(Dense(1))

# Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
# history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 85ms/step - loss: 0.0477 - val_loss: 0.0060
# Epoch 2/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0077 - val_loss: 0.0061
# Epoch 3/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 4/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 5/100
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 6/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 7/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 8/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 9/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 10/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 11/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 12/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 13/100
# 25/25 [==============================] - 3s 143ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 14/100
# 25/25 [==============================] - 2s 77ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 15/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 16/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 17/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 18/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 19/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 20/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 21/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 22/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 23/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 24/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 25/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 26/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 27/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 28/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 29/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 30/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 31/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 32/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 33/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 34/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 35/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 36/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 37/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 38/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 39/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 40/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 41/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 42/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 43/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 44/100
# 25/25 [==============================] - 2s 101ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 45/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 46/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 47/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 48/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 49/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 50/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 51/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 52/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 53/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 54/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 55/100
# 25/25 [==============================] - 1s 48ms/step - loss: 9.3116e-04 - val_loss: 0.0011
# Epoch 56/100
# 25/25 [==============================] - 1s 49ms/step - loss: 8.9809e-04 - val_loss: 0.0011
# Epoch 57/100
# 25/25 [==============================] - 1s 49ms/step - loss: 9.5714e-04 - val_loss: 0.0012
# Epoch 58/100
# 25/25 [==============================] - 2s 79ms/step - loss: 9.5212e-04 - val_loss: 0.0017
# Epoch 59/100
# 25/25 [==============================] - 1s 49ms/step - loss: 9.3627e-04 - val_loss: 0.0011
# Epoch 60/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 61/100
# 25/25 [==============================] - 2s 80ms/step - loss: 9.6763e-04 - val_loss: 9.9243e-04
# Epoch 62/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 63/100
# 25/25 [==============================] - 1s 49ms/step - loss: 9.6048e-04 - val_loss: 0.0010
# Epoch 64/100
# 25/25 [==============================] - 1s 48ms/step - loss: 8.7918e-04 - val_loss: 0.0012
# Epoch 65/100
# 25/25 [==============================] - 1s 50ms/step - loss: 9.8845e-04 - val_loss: 0.0022
# Epoch 66/100
# 25/25 [==============================] - 1s 51ms/step - loss: 8.3459e-04 - val_loss: 0.0013
# Epoch 67/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 68/100
# 25/25 [==============================] - 1s 49ms/step - loss: 8.6983e-04 - val_loss: 0.0012
# Epoch 69/100
# 25/25 [==============================] - 1s 48ms/step - loss: 7.7333e-04 - val_loss: 0.0029
# Epoch 70/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0011 - val_loss: 9.5118e-04
# Epoch 71/100
# 25/25 [==============================] - 2s 80ms/step - loss: 7.3694e-04 - val_loss: 9.0273e-04
# Epoch 72/100
# 25/25 [==============================] - 2s 83ms/step - loss: 7.4105e-04 - val_loss: 0.0012
# Epoch 73/100
# 25/25 [==============================] - 1s 49ms/step - loss: 8.1828e-04 - val_loss: 0.0017
# Epoch 74/100
# 25/25 [==============================] - 1s 48ms/step - loss: 9.2969e-04 - val_loss: 0.0013
# Epoch 75/100
# 25/25 [==============================] - 1s 48ms/step - loss: 7.4113e-04 - val_loss: 9.1976e-04
# Epoch 76/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.5737e-04 - val_loss: 0.0011
# Epoch 77/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.4863e-04 - val_loss: 9.6775e-04
# Epoch 78/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.0142e-04 - val_loss: 0.0018
# Epoch 79/100
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0012 - val_loss: 8.5956e-04
# Epoch 80/100
# 25/25 [==============================] - 2s 73ms/step - loss: 8.5448e-04 - val_loss: 8.7660e-04
# Epoch 81/100
# 25/25 [==============================] - 2s 79ms/step - loss: 7.1488e-04 - val_loss: 0.0012
# Epoch 82/100
# 25/25 [==============================] - 1s 48ms/step - loss: 7.6299e-04 - val_loss: 8.5723e-04
# Epoch 83/100
# 25/25 [==============================] - 1s 48ms/step - loss: 6.9617e-04 - val_loss: 0.0015
# Epoch 84/100
# 25/25 [==============================] - 3s 107ms/step - loss: 6.7724e-04 - val_loss: 8.3551e-04
# Epoch 85/100
# 25/25 [==============================] - 1s 57ms/step - loss: 6.3438e-04 - val_loss: 8.7254e-04
# Epoch 86/100
# 25/25 [==============================] - 1s 49ms/step - loss: 6.2972e-04 - val_loss: 0.0011
# Epoch 87/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.2789e-04 - val_loss: 0.0016
# Epoch 88/100
# 25/25 [==============================] - 1s 55ms/step - loss: 8.4524e-04 - val_loss: 0.0011
# Epoch 89/100
# 25/25 [==============================] - 2s 79ms/step - loss: 8.2322e-04 - val_loss: 0.0013
# Epoch 90/100
# 25/25 [==============================] - 2s 69ms/step - loss: 9.5966e-04 - val_loss: 0.0019
# Epoch 91/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.8520e-04 - val_loss: 7.8676e-04
# Epoch 92/100
# 25/25 [==============================] - 1s 50ms/step - loss: 5.8833e-04 - val_loss: 8.5575e-04
# Epoch 93/100
# 25/25 [==============================] - 1s 50ms/step - loss: 6.5179e-04 - val_loss: 7.7527e-04
# Epoch 94/100
# 25/25 [==============================] - 1s 48ms/step - loss: 6.0559e-04 - val_loss: 0.0011
# Epoch 95/100
# 25/25 [==============================] - 1s 49ms/step - loss: 7.1211e-04 - val_loss: 0.0014
# Epoch 96/100
# 25/25 [==============================] - 1s 52ms/step - loss: 5.9793e-04 - val_loss: 8.2159e-04
# Epoch 97/100
# 25/25 [==============================] - 2s 91ms/step - loss: 5.9322e-04 - val_loss: 0.0010
# Epoch 98/100
# 25/25 [==============================] - 2s 77ms/step - loss: 5.9881e-04 - val_loss: 7.8496e-04
# Epoch 99/100
# 25/25 [==============================] - 2s 75ms/step - loss: 5.4423e-04 - val_loss: 7.5238e-04
# Epoch 100/100
# 25/25 [==============================] - 1s 48ms/step - loss: 6.1881e-04 - val_loss: 9.8205e-04

# %%
from keras.layers import BatchNormalization

# Adding Dropout and Batch Normalization
model.add(Dropout(0.2))
model.add(BatchNormalization())

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  permute (Permute)           (None, 50, 60)            0
#
#  reshape (Reshape)           (None, 50, 60)            0
#
#  permute_1 (Permute)         (None, 60, 50)            0
#
#  reshape_1 (Reshape)         (None, 60, 50)            0
#
#  flatten (Flatten)           (None, 3000)              0
#
#  dense (Dense)               (None, 1)                 3001
#
#  dropout (Dropout)           (None, 1)                 0
#
#  batch_normalization (Batch  (None, 1)                 4
#  Normalization)
#
# =================================================================
# Total params: 33605 (131.27 KB)
# Trainable params: 33603 (131.26 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
# Assuming X_train and y_train are already defined and preprocessed
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 86ms/step - loss: 0.8870 - val_loss: 0.3496
# Epoch 2/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.4967 - val_loss: 0.4077
# Epoch 3/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.3058 - val_loss: 0.3311
# Epoch 4/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.2524 - val_loss: 0.3154
# Epoch 5/100
# 25/25 [==============================] - 1s 58ms/step - loss: 0.2157 - val_loss: 0.3072
# Epoch 6/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.1963 - val_loss: 0.2527
# Epoch 7/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.1714 - val_loss: 0.2319
# Epoch 8/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.1523 - val_loss: 0.2157
# Epoch 9/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.1390 - val_loss: 0.1943
# Epoch 10/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.1265 - val_loss: 0.1597
# Epoch 11/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.1272 - val_loss: 0.1737
# Epoch 12/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0995 - val_loss: 0.1515
# Epoch 13/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0874 - val_loss: 0.1331
# Epoch 14/100
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0824 - val_loss: 0.1084
# Epoch 15/100
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0702 - val_loss: 0.0946
# Epoch 16/100
# 25/25 [==============================] - 3s 108ms/step - loss: 0.0635 - val_loss: 0.0876
# Epoch 17/100
# 25/25 [==============================] - 3s 107ms/step - loss: 0.0574 - val_loss: 0.0901
# Epoch 18/100
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0495 - val_loss: 0.0760
# Epoch 19/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0470 - val_loss: 0.0554
# Epoch 20/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.0418 - val_loss: 0.0324
# Epoch 21/100
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0377 - val_loss: 0.0461
# Epoch 22/100
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0320 - val_loss: 0.0438
# Epoch 23/100
# 25/25 [==============================] - 3s 105ms/step - loss: 0.0287 - val_loss: 0.0454
# Epoch 24/100
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0253 - val_loss: 0.0137
# Epoch 25/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0247 - val_loss: 0.0427
# Epoch 26/100
# 25/25 [==============================] - 2s 59ms/step - loss: 0.0214 - val_loss: 0.0421
# Epoch 27/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0210 - val_loss: 0.0066
# Epoch 28/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0183 - val_loss: 0.0253
# Epoch 29/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0174 - val_loss: 0.0043
# Epoch 30/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0152 - val_loss: 0.0139
# Epoch 31/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0166 - val_loss: 0.0109
# Epoch 32/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0117 - val_loss: 0.0011
# Epoch 33/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0130 - val_loss: 0.0270
# Epoch 34/100
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0148 - val_loss: 9.1402e-04
# Epoch 35/100
# 25/25 [==============================] - 2s 76ms/step - loss: 0.0140 - val_loss: 0.0048
# Epoch 36/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0090 - val_loss: 0.0056
# Epoch 37/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0113 - val_loss: 0.0012
# Epoch 38/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 39/100
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0118 - val_loss: 0.0012
# Epoch 40/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0101 - val_loss: 0.0026
# Epoch 41/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0105 - val_loss: 8.9431e-04
# Epoch 42/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0090 - val_loss: 0.0211
# Epoch 43/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0103 - val_loss: 0.0034
# Epoch 44/100
# 25/25 [==============================] - 2s 74ms/step - loss: 0.0092 - val_loss: 8.2473e-04
# Epoch 45/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0110 - val_loss: 0.0080
# Epoch 46/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 47/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0089 - val_loss: 0.0013
# Epoch 48/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0107 - val_loss: 0.0054
# Epoch 49/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0103 - val_loss: 0.0010
# Epoch 50/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0115 - val_loss: 0.0075
# Epoch 51/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 52/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.0101 - val_loss: 0.0022
# Epoch 53/100
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0109 - val_loss: 7.8335e-04
# Epoch 54/100
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 55/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0102 - val_loss: 0.0016
# Epoch 56/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0092 - val_loss: 0.0012
# Epoch 57/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0112 - val_loss: 0.0052
# Epoch 58/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0108 - val_loss: 8.7485e-04
# Epoch 59/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 60/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0111 - val_loss: 8.6352e-04
# Epoch 61/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 0.0048
# Epoch 62/100
# 25/25 [==============================] - 2s 76ms/step - loss: 0.0105 - val_loss: 0.0038
# Epoch 63/100
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0124 - val_loss: 7.2788e-04
# Epoch 64/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0095 - val_loss: 0.0054
# Epoch 65/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0132 - val_loss: 0.0059
# Epoch 66/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 0.0012
# Epoch 67/100
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0109 - val_loss: 7.5657e-04
# Epoch 68/100
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0105 - val_loss: 0.0211
# Epoch 69/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0091 - val_loss: 0.0055
# Epoch 70/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0111 - val_loss: 0.0040
# Epoch 71/100
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0088 - val_loss: 0.0025
# Epoch 72/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 73/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0101 - val_loss: 0.0069
# Epoch 74/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 0.0010
# Epoch 75/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0114 - val_loss: 0.0039
# Epoch 76/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 7.4800e-04
# Epoch 77/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0108 - val_loss: 0.0032
# Epoch 78/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0099 - val_loss: 0.0031
# Epoch 79/100
# 25/25 [==============================] - 2s 62ms/step - loss: 0.0098 - val_loss: 9.5272e-04
# Epoch 80/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0087 - val_loss: 0.0016
# Epoch 81/100
# 25/25 [==============================] - 3s 111ms/step - loss: 0.0090 - val_loss: 6.6403e-04
# Epoch 82/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0080 - val_loss: 6.6442e-04
# Epoch 83/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0090 - val_loss: 7.5471e-04
# Epoch 84/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0089 - val_loss: 0.0030
# Epoch 85/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0099 - val_loss: 0.0043
# Epoch 86/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0097 - val_loss: 0.0188
# Epoch 87/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0105 - val_loss: 7.0926e-04
# Epoch 88/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0105 - val_loss: 0.0042
# Epoch 89/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0112 - val_loss: 9.2662e-04
# Epoch 90/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0104 - val_loss: 0.0033
# Epoch 91/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0103 - val_loss: 0.0034
# Epoch 92/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0123 - val_loss: 0.0038
# Epoch 93/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0107 - val_loss: 0.0018
# Epoch 94/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0116 - val_loss: 8.5398e-04
# Epoch 95/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0096 - val_loss: 7.8967e-04
# Epoch 96/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0095 - val_loss: 0.0014
# Epoch 97/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.0091 - val_loss: 0.0010
# Epoch 98/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0105 - val_loss: 0.0235
# Epoch 99/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0093 - val_loss: 9.3066e-04
# Epoch 100/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0115 - val_loss: 0.0030

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0107 - val_loss: 9.6484e-04
# Epoch 2/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0093 - val_loss: 7.5447e-04
# Epoch 3/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0091 - val_loss: 9.5406e-04
# Epoch 4/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0100 - val_loss: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0086 - val_loss: 0.0062
# Epoch 6/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 0.0052
# Epoch 7/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0125 - val_loss: 0.0187
# Epoch 8/100
# 25/25 [==============================] - 2s 74ms/step - loss: 0.0113 - val_loss: 0.0046
# Epoch 9/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0103 - val_loss: 9.7815e-04
# Epoch 10/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0109 - val_loss: 0.0051
# Epoch 11/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0083 - val_loss: 0.0054
# Epoch 12/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 8.7264e-04

# %%
# Convert X_test and y_test to Numpy arrays if they are not already
X_test = np.array(X_test)
y_test = np.array(y_test)

# Ensure X_test is reshaped similarly to how X_train was reshaped
# This depends on how you preprocessed the training data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Now evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print("Test Loss: ", test_loss)
# Out:
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0023
# Test Loss:  0.0023413433227688074

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Making predictions
y_pred = model.predict(X_test)

# Calculating MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("Mean Absolute Error: ", mae)

print("Root Mean Square Error: ", rmse)
# Out:
# 6/6 [==============================] - 1s 22ms/step
# Mean Absolute Error:  0.043710793728729415
# Root Mean Square Error:  0.04838743128525183

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetching the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='60d', interval='1d')

# Selecting the 'Close' price and converting to numpy array
closing_prices = data['Close'].values

# Scaling the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1,1))

# Since we need the last 60 days to predict the next day, we reshape the data accordingly
X_latest = np.array([scaled_data[-60:].reshape(60)])

# Reshaping the data for the model (adding batch dimension)
X_latest = np.reshape(X_latest, (X_latest.shape[0], X_latest.shape[1], 1))

# Making predictions for the next 4 candles
predicted_stock_price = model.predict(X_latest)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

print("Predicted Stock Prices for the next 4 days: ", predicted_stock_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 36ms/step
# Predicted Stock Prices for the next 4 days:  [[188.14558]]

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetch the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='60d', interval='1d')

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    # Get the prediction (next day)
    next_prediction = model.predict(current_batch)

    # Reshape the prediction to fit the batch dimension
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)

    # Append the prediction to the batch used for predicting
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)

    # Inverse transform the prediction to the original price scale
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

print("Predicted Stock Prices for the next 4 days: ", predicted_prices)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# Predicted Stock Prices for the next 4 days:  [188.14558, 186.82628, 185.65448, 183.84601]

# %%
# !pip install mplfinance -qqq
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame with the fetched AAPL stock data
# Make sure it contains Open, High, Low, Close, and Volume columns

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Assuming 'predicted_prices' is your list of predicted prices for the next 4 days
predictions_df = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Plotting the actual data with mplfinance
mpf.plot(data, type='candle', style='charles', volume=True)

# Overlaying the predicted data
plt.figure(figsize=(10,6))
plt.plot(predictions_df.index, predictions_df['Close'], linestyle='dashed', marker='o', color='red')

plt.title("AAPL Stock Price with Predicted Next 4 Days")
plt.show()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.3 MB/s eta 0:00:00

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Fetch the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='64d', interval='1d') # Fetch 64 days to display last 60 days in the chart

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    next_prediction = model.predict(current_batch)
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Adding predictions to the DataFrame
predicted_data = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Combining both actual and predicted data
combined_data = pd.concat([data['Close'], predicted_data['Close']])
combined_data = combined_data[-64:] # Last 60 days of actual data + 4 days of predictions

# Plotting the actual data
plt.figure(figsize=(10,6))
plt.plot(data.index[-60:], data['Close'][-60:], linestyle='-', marker='o', color='blue', label='Actual Data')

# Plotting the predicted data
plt.plot(prediction_dates, predicted_prices, linestyle='-', marker='o', color='red', label='Predicted Data')

plt.title("AAPL Stock Price: Last 60 Days and Next 4 Days Predicted")
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta

def predict_stock_price(input_date):
    # Check if the input date is a valid date format
    try:
        input_date = pd.to_datetime(input_date)
    except ValueError:
        print("Invalid Date Format. Please enter date in YYYY-MM-DD format.")
        return

    # Fetch data from yfinance
    end_date = input_date
    start_date = input_date - timedelta(days=90)  # Fetch more days to ensure we have 60 trading days
    data = yf.download('AAPL', start=start_date, end=end_date)

    if len(data) < 60:
        print("Not enough historical data to make a prediction. Try an earlier date.")
        return

    # Prepare the data
    closing_prices = data['Close'].values[-60:]  # Last 60 days
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

    # Make predictions
    predicted_prices = []
    current_batch = scaled_data.reshape(1, 60, 1)

    for i in range(4):  # Predicting 4 days
        next_prediction = model.predict(current_batch)
        next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
        current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
        predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

    # Output the predictions
    for i, price in enumerate(predicted_prices, 1):
        print(f"Day {i} prediction: {price}")

# Example use
user_input = input("Enter a date (YYYY-MM-DD) to predict AAPL stock for the next 4 days: ")
predict_stock_price(user_input)
